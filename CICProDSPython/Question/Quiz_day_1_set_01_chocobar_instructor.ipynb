# %% [markdown]
# # 다음 퀴즈를 수행하시오.

# %% [markdown]
# ### Q1. pandas 모듈을 pd로 불러오시오.

# %%
import pandas as pd

# %% [markdown]
# ### Q2. "rating_chocobar.csv"를 pandas 모듈을 활용하여 불러오고 객체 종류를 확인하시오
# (단, df 객체에 저장하시오)

# %%
df = pd.read_csv("rating_chocobar.csv")

# %% [markdown]
# ### Q3. df의 첫 3개 row를 출력하시오

# %%
df.head(3)
# Out:
#   Company_Maker_if_known Specific_Bean_Origin_or_Bar_Name   REF  Review_Date  \
# 0               A. Morin                      Agua Grande  1876         2016
# 1               A. Morin                            Kpime  1676         2015
# 2               A. Morin                           Atsane  1676         2015
#
#   Cocoa_Percent Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           63%           France    3.75       NaN          Sao Tome
# 1           70%           France    2.75       NaN              Togo
# 2           70%           France    3.00       NaN              Togo

# %% [markdown]
# ### Q4. df의 마지막 2개 row를 출력하시오

# %%
df.tail(2)
# Out:
#      Company_Maker_if_known Specific_Bean_Origin_or_Bar_Name  REF  \
# 1793                 Zotter                     Kerala State  781
# 1794                 Zotter               Brazil, Mitzi Blue  486
#
#       Review_Date Cocoa_Percent Company_Location  Rating Bean_Type  \
# 1793         2011           62%          Austria    3.25       NaN
# 1794         2010           65%          Austria    3.00       NaN
#
#      Broad_Bean_Origin
# 1793             India
# 1794            Brazil

# %% [markdown]
# ### Q5. df의 차원을 확인하시오

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ### Q6. df의 row 개수를 확인하시오

# %%
df.shape[0]
len(df)
# Out:
# 1795

# %% [markdown]
# ### Q7. df의 column 개수를 확인하시오

# %%
df.shape[1]
len(df.columns)
# Out:
# 9

# %% [markdown]
# ### Q8. df의 column 이름을 확인하시오

# %%
df.columns
# Out:
# Index(['Company_Maker_if_known', 'Specific_Bean_Origin_or_Bar_Name', 'REF',
#        'Review_Date', 'Cocoa_Percent', 'Company_Location', 'Rating',
#        'Bean_Type', 'Broad_Bean_Origin'],
#       dtype='object')

# %% [markdown]
# ### Q9. df의 첫 번째 변수 명을 "aa"로 변경하시오

# %%
# 1)
df = df.rename(columns = {"Company_Maker_if_known": "aa"})
df.columns

# 2)
df = df.rename(columns = {df.columns[0]: "aa"})
df.columns
# Out:
# Index(['aa', 'Specific_Bean_Origin_or_Bar_Name', 'REF', 'Review_Date',
#        'Cocoa_Percent', 'Company_Location', 'Rating', 'Bean_Type',
#        'Broad_Bean_Origin'],
#       dtype='object')

# %% [markdown]
# ### Q10. df의 첫 번째, 네 번째, 열 번째 row를 추출하여 df_sub1 객체에 저장하시오

# %%
# 1
df_sub1 = df.take([0, 3, 9])
df_sub1
# Out:
#          aa Specific_Bean_Origin_or_Bar_Name   REF  Review_Date Cocoa_Percent  \
# 0  A. Morin                      Agua Grande  1876         2016           63%
# 3  A. Morin                            Akata  1680         2015           70%
# 9  A. Morin                          Pablino  1319         2014           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75       NaN          Sao Tome
# 3           France    3.50       NaN              Togo
# 9           France    4.00       NaN              Peru

# %%
# 2
df_sub1 = df.iloc[[0, 3, 9], :]
df_sub1
# Out:
#          aa Specific_Bean_Origin_or_Bar_Name   REF  Review_Date Cocoa_Percent  \
# 0  A. Morin                      Agua Grande  1876         2016           63%
# 3  A. Morin                            Akata  1680         2015           70%
# 9  A. Morin                          Pablino  1319         2014           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75       NaN          Sao Tome
# 3           France    3.50       NaN              Togo
# 9           France    4.00       NaN              Peru

# %% [markdown]
# ### Q11. df의 index 번호가 짝수인 것만 추출하여 df_sub2 객체에 저장하시오

# %%
# 1)
import numpy as np
df_sub2 = df.iloc[np.arange(len(df)/2)*2,]
df_sub2.head()

# 2)
len(df)
df_sub2 = df.iloc[2:1795:2, :]

# 3)
df_sub2 = df.iloc[2:len(df):2, :]

# 4)
df_sub2 = df.iloc[2::2, :]
df_sub2.tail(2)

# 5)
df.iloc[::2, :]
# Out:
#                          aa          Specific_Bean_Origin_or_Bar_Name   REF  \
# 0                  A. Morin                               Agua Grande  1876
# 2                  A. Morin                                    Atsane  1676
# 4                  A. Morin                                    Quilla  1704
# 6                  A. Morin                                      Cuba  1315
# 8                  A. Morin                            Puerto Cabello  1319
# 10                 A. Morin                                    Panama  1011
# 12                 A. Morin                                    Brazil  1011
# 14                 A. Morin                                  Colombie  1015
# 16                 A. Morin                          Papua New Guinea  1015
# 18                 A. Morin                                     Piura  1019
# 20                 A. Morin                      Chanchamayo Province  1019
# 22                 A. Morin                                      Peru   797
# 24                   Acalli                         Tumbes, Norandino  1470
# 26                      Adi                        Vanua Levu, Toto-A   705
# 28                      Adi                    Vanua Levu, Ami-Ami-CA   705
# 30       Aequare (Gianduja)                 Los Rios, Quevedo, Arriba   370
# 32       Akesson's (Pralus)  Bali (west), Sukrama Family, Melaya area   636
# 34       Akesson's (Pralus)                   Monte Alegre, D. Badero   508
# 36            Alain Ducasse                                   Vietnam  1215
# 38            Alain Ducasse                                     Chuao  1061
# 40                Alexandre                          Winak Coop, Napo  1944
# 42                Alexandre                                Tien Giang  1944
# 44    Altus aka Cao Artisan                                 Momotombo  1728
# 46    Altus aka Cao Artisan                                CIAAB Coop  1732
# 48    Altus aka Cao Artisan                            Gruppo Salinas  1732
# 50    Altus aka Cao Artisan                                  Conacado  1125
# 52    Altus aka Cao Artisan                                   Bolivia  1133
# 54                    Amano                                    Morobe   725
# 56                    Amano                                    Guayas   470
# 58                    Amano                                  Montanya   363
# ...                     ...                                       ...   ...
# 1736       Wilkie's Organic                                  Amazonas  1169
# 1738       Wilkie's Organic                          Amazonas w/ nibs  1173
# 1740         Willie's Cacao                                Los Llanos  1227
# 1742         Willie's Cacao                                 Sambirano   593
# 1744         Willie's Cacao                                      Java   593
# 1746         Willie's Cacao                                Rio Caribe   457
# 1748                     Wm   Wild Beniano, 2016, batch 128, Heirloom  1912
# 1750              Woodblock                        Maranon, Cajamarca  1243
# 1752              Woodblock                                Gran Couva  1042
# 1754              Woodblock                                Costa Rica   825
# 1756              Woodblock                                   Ocumare   741
# 1778         2014           80%            Austria    2.75
# 1780         2012           65%            Austria    3.50
# 1782         2012           70%            Austria    3.50
# 1784         2012           75%            Austria    3.00
# 1786         2012           90%            Austria    3.25
# 1788         2012           68%            Austria    3.25
# 1790         2011           70%            Austria    3.75
# 1792         2011           65%            Austria    3.50
# 1794         2010           65%            Austria    3.00
#
#                  Bean_Type   Broad_Bean_Origin
# 0                      NaN            Sao Tome
# 2                      NaN                Togo
# 4                      NaN                Peru
# 6                      NaN                Cuba
# 8                  Criollo           Venezuela
# 10                     NaN              Panama
# 12                     NaN              Brazil
# 14                     NaN            Colombia
# 16                     NaN    Papua New Guinea
# 18                     NaN                Peru
# 20                     NaN                Peru
# 22                     NaN                Peru
# 24                 Criollo                Peru
# 26              Trinitario                Fiji
# 28              Trinitario                Fiji
# 30      Forastero (Arriba)             Ecuador
# 32              Trinitario           Indonesia
# 34               Forastero              Brazil
# 36              Trinitario             Vietnam
# 38              Trinitario           Venezuela
# 40    Forastero (Nacional)             Ecuador
# 42              Trinitario             Vietnam
# 44                     NaN           Nicaragua
# 46                     NaN             Bolivia
# 48                     NaN             Ecuador
# 50              Trinitario  Dominican Republic
# 52                     NaN             Bolivia
# 54                     NaN    Papua New Guinea
# 56                     NaN             Ecuador
# 58                     NaN           Venezuela
# ...                    ...                 ...
# 1736               Criollo                Peru
# 1738               Criollo                Peru
# 1740            Trinitario            Colombia
# 1742            Trinitario          Madagascar
# 1744                   NaN           Indonesia
# 1746            Trinitario           Venezuela
# 1748                   NaN             Bolivia
# 1750  Forastero (Nacional)                Peru
# 1752            Trinitario            Trinidad
# 1754                   NaN          Costa Rica
# 1756                   NaN           Venezuela
# 1758                   NaN  Dominican Republic
# 1760                   NaN  Dominican Republic
# 1762                   NaN   Domincan Republic
# 1764                   NaN                Peru
# 1766                   NaN                 NaN
# 1768     Nacional (Arriba)             Ecuador
# 1770   Criollo, Trinitario            Tanzania
# 1772            Trinitario            Trinidad
# 1774                   NaN                 NaN
# 1776            Trinitario    Papua New Guinea
# 1778                   NaN                 NaN
# 1780                   NaN                 NaN
# 1782      Criollo (Amarru)                Peru
# 1784  Forastero (Nacional)             Ecuador
# 1786                   NaN             Bolivia
# 1788             Forastero               Congo
# 1790                   NaN                Peru
# 1792             Forastero               India
# 1794                   NaN              Brazil
#
# [898 rows x 9 columns]

# %% [markdown]
# ### Q12. df_sub1과 df_sub2를 차례대로 병합하여 df_sub 객체에 저장하시오

# %%
# 1)
df_sub = df_sub1.append(df_sub2)
df_sub.head()
# Out:
#          aa Specific_Bean_Origin_or_Bar_Name   REF  Review_Date Cocoa_Percent  \
# 0  A. Morin                      Agua Grande  1876         2016           63%
# 3  A. Morin                            Akata  1680         2015           70%
# 9  A. Morin                          Pablino  1319         2014           70%
# 2  A. Morin                           Atsane  1676         2015           70%
# 4  A. Morin                           Quilla  1704         2015           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75       NaN          Sao Tome
# 3           France    3.50       NaN              Togo
# 9           France    4.00       NaN              Peru
# 2           France    3.00       NaN              Togo
# 4           France    3.50       NaN              Peru

# %%
# 2)
df_sub = pd.concat([df_sub1, df_sub2], axis = 0)
df_sub.head()
# Out:
#          aa Specific_Bean_Origin_or_Bar_Name   REF  Review_Date Cocoa_Percent  \
# 0  A. Morin                      Agua Grande  1876         2016           63%
# 3  A. Morin                            Akata  1680         2015           70%
# 9  A. Morin                          Pablino  1319         2014           70%
# 2  A. Morin                           Atsane  1676         2015           70%
# 4  A. Morin                           Quilla  1704         2015           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75       NaN          Sao Tome
# 3           France    3.50       NaN              Togo
# 9           France    4.00       NaN              Peru
# 2           France    3.00       NaN              Togo
# 4           France    3.50       NaN              Peru

# %%
# !?)
pd.concat([df_sub1.iloc[:3, :], df_sub2.iloc[:3, :]], axis = 1)
# Out:
#          aa Specific_Bean_Origin_or_Bar_Name     REF  Review_Date  \
# 0  A. Morin                      Agua Grande  1876.0       2016.0
# 2       NaN                              NaN     NaN          NaN
# 3  A. Morin                            Akata  1680.0       2015.0
# 4       NaN                              NaN     NaN          NaN
# 6       NaN                              NaN     NaN          NaN
# 9  A. Morin                          Pablino  1319.0       2014.0
#
#   Cocoa_Percent Company_Location  Rating Bean_Type Broad_Bean_Origin  \
# 0           63%           France    3.75       NaN          Sao Tome
# 2           NaN              NaN     NaN       NaN               NaN
# 3           70%           France    3.50       NaN              Togo
# 4           NaN              NaN     NaN       NaN               NaN
# 6           NaN              NaN     NaN       NaN               NaN
# 9           70%           France    4.00       NaN              Peru
#
#          aa Specific_Bean_Origin_or_Bar_Name     REF  Review_Date  \
# 0       NaN                              NaN     NaN          NaN
# 2  A. Morin                           Atsane  1676.0       2015.0
# 3       NaN                              NaN     NaN          NaN
# 4  A. Morin                           Quilla  1704.0       2015.0
# 6  A. Morin                             Cuba  1315.0       2014.0
# 9       NaN                              NaN     NaN          NaN
#
#   Cocoa_Percent Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           NaN              NaN     NaN       NaN               NaN
# 2           70%           France     3.0       NaN              Togo
# 3           NaN              NaN     NaN       NaN               NaN
# 4           70%           France     3.5       NaN              Peru
# 6           70%           France     3.5       NaN              Cuba
# 9           NaN              NaN     NaN       NaN               NaN

# %% [markdown]
# ### Q13. df_sub를 "quiz.csv"로 저장하시오.

# %%
df_sub = df_sub.reset_index()
df_sub.head()
# Out:
#    index        aa Specific_Bean_Origin_or_Bar_Name   REF  Review_Date  \
# 0      0  A. Morin                      Agua Grande  1876         2016
# 1      3  A. Morin                            Akata  1680         2015
# 2      9  A. Morin                          Pablino  1319         2014
# 3      2  A. Morin                           Atsane  1676         2015
# 4      4  A. Morin                           Quilla  1704         2015
#
#   Cocoa_Percent Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           63%           France    3.75       NaN          Sao Tome
# 1           70%           France    3.50       NaN              Togo
# 2           70%           France    4.00       NaN              Peru
# 3           70%           France    3.00       NaN              Togo
# 4           70%           France    3.50       NaN              Peru

# %%
df_sub.to_csv("quiz.csv", index=False)
