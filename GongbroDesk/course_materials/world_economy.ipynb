# %% [markdown]
# # World Economic Outlook Data Analysis
# Data Source : IMF

# %%
import pandas as pd
df = pd.read_csv('WEOApr2020all.csv')
df.head(3)
# Out:
#    WEO Country Code  ISO WEO Subject Code      Country  \
# 0               512  AFG        NGDP_RPCH  Afghanistan
# 1               512  AFG           PPPGDP  Afghanistan
# 2               512  AFG    NGDPRPPPPCPCH  Afghanistan
#
#                                   Subject Descriptor  \
# 0            Gross domestic product, constant prices
# 1             Gross domestic product, current prices
# 2  Gross domestic product per capita, constant pr...
#
#                                        Subject Notes  \
# 0  Annual percentages of constant price GDP are y...
# 1  These data form the basis for the country weig...
# 2  GDP is expressed in constant international dol...
#
#                                             Units     Scale  \
# 0                                  Percent change       NaN
# 1  Purchasing power parity; international dollars  Billions
# 2         Purchasing power parity; percent change       NaN
#
#                        Country/Series-specific Notes 1980  ...    2013  \
# 0  Source: National Statistics Office Latest actu...  NaN  ...   5.683
# 1  Source: National Statistics Office Latest actu...  NaN  ...  60.181
# 2  Source: National Statistics Office Latest actu...  NaN  ...   2.236
#
#      2014    2015    2016    2017    2018    2019    2020    2021  \
# 0   2.697   0.988   2.164   2.889   2.664   3.037  -3.007   4.495
# 1  62.948  64.231  66.301  69.501  73.091  76.624  74.792  79.678
# 2  -0.521  -1.941  -0.547   0.358   1.268   1.654  -4.291   3.063
#
#   Estimates Start After
# 0                2018.0
# 1                2018.0
# 2                2018.0
#
# [3 rows x 52 columns]

# %%
df.describe()
# Out:
#        WEO Country Code  Estimates Start After
# count       1552.000000            1466.000000
# mean         553.670103            2018.291951
# std          261.437803               1.075652
# min          111.000000            2009.000000
# 25%          314.000000            2018.000000
# 50%          571.000000            2018.000000
# 75%          734.000000            2019.000000
# max          968.000000            2020.000000

# %%
df.columns
# Out:
# Index(['WEO Country Code', 'ISO', 'WEO Subject Code', 'Country',
#        'Subject Descriptor', 'Subject Notes', 'Units', 'Scale',
#        'Country/Series-specific Notes', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', 'Estimates Start After'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Country'].nunique()
# Out:
# 194

# %%
df.iloc[:,::3]
# Out:
#       WEO Country Code      Country  \
# 0                  512  Afghanistan
# 1                  512  Afghanistan
# 2                  512  Afghanistan
# 3                  512  Afghanistan
# 4                  512  Afghanistan
# ...                ...          ...
# 1547               698     Zimbabwe
# 1548               698     Zimbabwe
# 1549               698     Zimbabwe
# 1550               698     Zimbabwe
# 1551               698     Zimbabwe
#
#                                                Units 1980    1983    1986  \
# 0                                     Percent change  NaN     NaN     NaN
# 1     Purchasing power parity; international dollars  NaN     NaN     NaN
# 2            Purchasing power parity; percent change  NaN     NaN     NaN
# 3                                     Percent change  NaN     NaN     NaN
# 4                                     Percent change  NaN     NaN     NaN
# ...                                              ...  ...     ...     ...
# 1547                                  Percent change  NaN  -8.452  10.666
# 1548                                  Percent change  NaN     NaN     NaN
# 1549                    Percent of total labor force  NaN     NaN     NaN
# 1550                                  Percent of GDP  NaN     NaN     NaN
# 1551                                  Percent of GDP  NaN     NaN     NaN
#
#         1989     1992    1995     1998     2001     2004     2007     2010  \
# 0        NaN      NaN     NaN      NaN      NaN    0.671    13.34    8.438
# 1        NaN      NaN     NaN      NaN      NaN   21.557   31.404   44.323
# 2        NaN      NaN     NaN      NaN      NaN   -3.112    9.143    5.431
# 3        NaN      NaN     NaN      NaN      NaN   16.358    8.681    2.179
# 4        NaN      NaN     NaN      NaN      NaN   13.266   16.092   10.246
# ...      ...      ...     ...      ...      ...      ...      ...      ...
# 1547  -3.847   -2.998  15.227  -28.023  -37.198  113.569  -72.729    3.045
# 1548     NaN      NaN     NaN      NaN      NaN      NaN      NaN    3.217
# 1549     NaN      NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 1550     NaN      NaN     NaN      NaN      NaN      NaN   -2.523    0.619
# 1551     NaN  -10.804  -4.466   -1.312    3.248   -1.353    3.829  -11.989
#
#         2013    2016     2019  Estimates Start After
# 0      5.683   2.164    3.037                 2018.0
# 1     60.181  66.301   76.624                 2018.0
# 2      2.236  -0.547    1.654                 2018.0
# 3      7.386   4.384    2.302                 2018.0
# 4      7.241   4.588    2.773                 2018.0
# ...      ...     ...      ...                    ...
# 1547   1.632  -1.558  255.292                 2019.0
# 1548   0.331  -0.898   521.15                 2019.0
# 1549     NaN     NaN      NaN                    NaN
# 1550  -0.621  -6.242   -2.575                 2018.0
# 1551  -13.23   -3.58    1.133                 2018.0
#
# [1552 rows x 18 columns]

# %%
df['Subject Descriptor'].head(7)
# Out:
# 0              Gross domestic product, constant prices
# 1               Gross domestic product, current prices
# 2    Gross domestic product per capita, constant pr...
# 3                   Inflation, average consumer prices
# 4             Inflation, end of period consumer prices
# 5                                    Unemployment rate
# 6             General government net lending/borrowing
# Name: Subject Descriptor, dtype: object

# %%
df[['Country','Subject Descriptor','2020']]
# Out:
#           Country                                 Subject Descriptor     2020
# 0     Afghanistan            Gross domestic product, constant prices   -3.007
# 1     Afghanistan             Gross domestic product, current prices   74.792
# 2     Afghanistan  Gross domestic product per capita, constant pr...   -4.291
# 3     Afghanistan                 Inflation, average consumer prices    4.711
# 4     Afghanistan           Inflation, end of period consumer prices      4.5
# ...           ...                                                ...      ...
# 1547     Zimbabwe                 Inflation, average consumer prices  319.036
# 1548     Zimbabwe           Inflation, end of period consumer prices  154.297
# 1549     Zimbabwe                                  Unemployment rate      NaN
# 1550     Zimbabwe           General government net lending/borrowing   -4.931
# 1551     Zimbabwe                            Current account balance   -1.914
#
# [1552 rows x 3 columns]

# %% [markdown]
# # Inflation

# %%
idx_inf = df['Subject Descriptor'].str.contains('Inflation, end of')
print(idx_inf)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1547    False
# 1548     True
# 1549    False
# 1550    False
# 1551    False
# Name: Subject Descriptor, Length: 1552, dtype: bool

# %%
df.loc[idx_inf]
# Out:
#       WEO Country Code  ISO WEO Subject Code              Country  \
# 4                  512  AFG         PCPIEPCH          Afghanistan
# 12                 914  ALB         PCPIEPCH              Albania
# 20                 612  DZA         PCPIEPCH              Algeria
# 28                 614  AGO         PCPIEPCH               Angola
# 36                 311  ATG         PCPIEPCH  Antigua and Barbuda
# ...                ...  ...              ...                  ...
# 1516               299  VEN         PCPIEPCH            Venezuela
# 1524               582  VNM         PCPIEPCH              Vietnam
# 1532               474  YEM         PCPIEPCH                Yemen
# 1540               754  ZMB         PCPIEPCH               Zambia
# 1548               698  ZWE         PCPIEPCH             Zimbabwe
#
#                             Subject Descriptor  \
# 4     Inflation, end of period consumer prices
# 12    Inflation, end of period consumer prices
# 20    Inflation, end of period consumer prices
# 28    Inflation, end of period consumer prices
# 36    Inflation, end of period consumer prices
# ...                                        ...
# 1516  Inflation, end of period consumer prices
# 1524  Inflation, end of period consumer prices
# 1532  Inflation, end of period consumer prices
# 1540  Inflation, end of period consumer prices
# 1548  Inflation, end of period consumer prices
#
#                                           Subject Notes           Units Scale  \
# 4      Annual percentages of end of period consumer ...  Percent change   NaN
# 12     Annual percentages of end of period consumer ...  Percent change   NaN
# 20     Annual percentages of end of period consumer ...  Percent change   NaN
# 28     Annual percentages of end of period consumer ...  Percent change   NaN
# 36     Annual percentages of end of period consumer ...  Percent change   NaN
# ...                                                 ...             ...   ...
# 1516   Annual percentages of end of period consumer ...  Percent change   NaN
# 1524   Annual percentages of end of period consumer ...  Percent change   NaN
# 1532   Annual percentages of end of period consumer ...  Percent change   NaN
# 1540   Annual percentages of end of period consumer ...  Percent change   NaN
# 1548   Annual percentages of end of period consumer ...  Percent change   NaN
#
#                           Country/Series-specific Notes    1980  ...    2013  \
# 4     Source: National Statistics Office Latest actu...     NaN  ...   7.241
# 12    Source: National Statistics Office Latest actu...     NaN  ...   1.776
# 20    Source: National Statistics Office Latest actu...  14.143  ...   1.148
# 28    Source: National Statistics Office Latest actu...     NaN  ...   7.687
# 36    Source: Central Bank Latest actual data: 2018 ...   17.71  ...   1.059
# ...                                                 ...     ...  ...     ...
# 1516  Source: Central Bank Latest actual data: 2019 ...     NaN  ...  56.193
# 1524  Source: National Statistics Office Latest actu...     NaN  ...   6.036
# 1532  Source: National Statistics Office. Central Ba...     NaN  ...    8.14
# 1540  Source: National Statistics Office Latest actu...     NaN  ...    7.14
# 1548  Source: National Statistics Office Latest actu...     NaN  ...   0.331
#
#         2014    2015     2016     2017        2018      2019       2020  \
# 4      1.487   1.131    4.588    3.041       0.755     2.773        4.5
# 12     0.719   1.937    2.176    1.798       1.799      1.15        2.6
# 20     5.253   4.362    6.957    4.933       2.702     2.434        3.3
# 28     7.498  12.091   41.125   23.667      18.604    16.893     20.979
# 36     1.327     0.9   -1.121    2.356       1.741     1.574      1.348
# ...      ...     ...      ...      ...         ...       ...        ...
# 1516   68.54  180.87  274.354  862.629  130,060.24  9,585.49  15,000.00
# 1524   1.839   0.597    4.737    2.597       2.983     5.237          2
# 1532  10.005      34     11.9       47        14.3       6.2         46
# 1540   7.862  21.112    7.469    6.085         7.9      11.7       12.7
# 1548  -0.796  -2.473   -0.898     3.43      42.074    521.15    154.297
#
#            2021 Estimates Start After
# 4             5                2018.0
# 12          2.9                2019.0
# 20            4                2019.0
# 28       23.981                2019.0
# 36        2.008                2018.0
# ...         ...                   ...
# 1516  15,000.00                2019.0
# 1524        4.3                2018.0
# 1532          5                2017.0
# 1540       11.4                2019.0
# 1548          3                2019.0
#
# [194 rows x 52 columns]

# %%
df_inf = df[idx_inf]
df_inf.head(3)
# Out:
#     WEO Country Code  ISO WEO Subject Code      Country  \
# 4                512  AFG         PCPIEPCH  Afghanistan
# 12               914  ALB         PCPIEPCH      Albania
# 20               612  DZA         PCPIEPCH      Algeria
#
#                           Subject Descriptor  \
# 4   Inflation, end of period consumer prices
# 12  Inflation, end of period consumer prices
# 20  Inflation, end of period consumer prices
#
#                                         Subject Notes           Units Scale  \
# 4    Annual percentages of end of period consumer ...  Percent change   NaN
# 12   Annual percentages of end of period consumer ...  Percent change   NaN
# 20   Annual percentages of end of period consumer ...  Percent change   NaN
#
#                         Country/Series-specific Notes    1980  ...   2013  \
# 4   Source: National Statistics Office Latest actu...     NaN  ...  7.241
# 12  Source: National Statistics Office Latest actu...     NaN  ...  1.776
# 20  Source: National Statistics Office Latest actu...  14.143  ...  1.148
#
#      2014   2015   2016   2017   2018   2019 2020 2021 Estimates Start After
# 4   1.487  1.131  4.588  3.041  0.755  2.773  4.5    5                2018.0
# 12  0.719  1.937  2.176  1.798  1.799   1.15  2.6  2.9                2019.0
# 20  5.253  4.362  6.957  4.933  2.702  2.434  3.3    4                2019.0
#
# [3 rows x 52 columns]

# %%
df_inf_2021 = df_inf[['Country','2021']]
df_inf_2021
# Out:
#                   Country       2021
# 4             Afghanistan          5
# 12                Albania        2.9
# 20                Algeria          4
# 28                 Angola     23.981
# 36    Antigua and Barbuda      2.008
# ...                   ...        ...
# 1516            Venezuela  15,000.00
# 1524              Vietnam        4.3
# 1532                Yemen          5
# 1540               Zambia       11.4
# 1548             Zimbabwe          3
#
# [194 rows x 2 columns]

# %%
df_inf_2021.reset_index(drop=True, inplace=True)
df_inf_2021
# Out:
#                  Country       2021
# 0            Afghanistan          5
# 1                Albania        2.9
# 2                Algeria          4
# 3                 Angola     23.981
# 4    Antigua and Barbuda      2.008
# ..                   ...        ...
# 189            Venezuela  15,000.00
# 190              Vietnam        4.3
# 191                Yemen          5
# 192               Zambia       11.4
# 193             Zimbabwe          3
#
# [194 rows x 2 columns]

# %%
df_inf_2021.dtypes
# Out:
# Country    object
# 2021       object
# dtype: object

# %%
df_inf_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  194 non-null    object
#  1   2021     190 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
# get only non-null data type
df_inf_2021 = df_inf_2021.loc[df_inf_2021['2021'].notnull()]
df_inf_2021
# Out:
#                  Country       2021
# 0            Afghanistan          5
# 1                Albania        2.9
# 2                Algeria          4
# 3                 Angola     23.981
# 4    Antigua and Barbuda      2.008
# ..                   ...        ...
# 189            Venezuela  15,000.00
# 190              Vietnam        4.3
# 191                Yemen          5
# 192               Zambia       11.4
# 193             Zimbabwe          3
#
# [190 rows x 2 columns]

# %%
df_inf_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 193
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  190 non-null    object
#  1   2021     190 non-null    object
# dtypes: object(2)
# memory usage: 4.5+ KB

# %%
df_inf_2021 = df_inf_2021.replace(',','',regex=True)
df_inf_2021
# Out:
#                  Country      2021
# 0            Afghanistan         5
# 1                Albania       2.9
# 2                Algeria         4
# 3                 Angola    23.981
# 4    Antigua and Barbuda     2.008
# ..                   ...       ...
# 189            Venezuela  15000.00
# 190              Vietnam       4.3
# 191                Yemen         5
# 192               Zambia      11.4
# 193             Zimbabwe         3
#
# [190 rows x 2 columns]

# %%
# change to numeric
df_inf_2021['2021'] = pd.to_numeric(df_inf_2021['2021'])
df_inf_2021
# Out:
#                  Country       2021
# 0            Afghanistan      5.000
# 1                Albania      2.900
# 2                Algeria      4.000
# 3                 Angola     23.981
# 4    Antigua and Barbuda      2.008
# ..                   ...        ...
# 189            Venezuela  15000.000
# 190              Vietnam      4.300
# 191                Yemen      5.000
# 192               Zambia     11.400
# 193             Zimbabwe      3.000
#
# [190 rows x 2 columns]

# %%
df_inf_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 193
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  190 non-null    object
#  1   2021     190 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.5+ KB

# %%
# plot bar graph
df_inf_2021.sort_values('2021').plot.bar(x='Country')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
df_inf_2021.sort_values('2021').iloc[0:20,:].plot.bar(x='Country')
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# # Unemployment Rate

# %%
df_ur = df[ df['Subject Descriptor'].str.contains('Unemployment')][['Country','2021']]
df_ur
# Out:
#                   Country    2021
# 5             Afghanistan     NaN
# 13                Albania    11.5
# 21                Algeria  13.909
# 29                 Angola     NaN
# 37    Antigua and Barbuda     NaN
# ...                   ...     ...
# 1517            Venezuela     NaN
# 1525              Vietnam     NaN
# 1533                Yemen     NaN
# 1541               Zambia     NaN
# 1549             Zimbabwe     NaN
#
# [194 rows x 2 columns]

# %%
df_ur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194 entries, 5 to 1549
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  194 non-null    object
#  1   2021     100 non-null    object
# dtypes: object(2)
# memory usage: 4.5+ KB

# %%
df_ur = df_ur.loc[df_ur['2021'].notnull()]
df_ur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 13 to 1493
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  100 non-null    object
#  1   2021     100 non-null    object
# dtypes: object(2)
# memory usage: 2.3+ KB

# %%
df_ur.reset_index(drop=True, inplace=True)
df_ur
# Out:
#            Country    2021
# 0          Albania    11.5
# 1          Algeria  13.909
# 2        Argentina  10.084
# 3          Armenia  18.389
# 4            Aruba   7.458
# ..             ...     ...
# 95          Turkey  15.567
# 96         Ukraine   9.318
# 97  United Kingdom   4.375
# 98   United States   9.135
# 99         Uruguay   8.098
#
# [100 rows x 2 columns]

# %%
df_ur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  100 non-null    object
#  1   2021     100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
df_ur['2021'] = pd.to_numeric(df_ur['2021'])
df_ur
# Out:
#            Country    2021
# 0          Albania  11.500
# 1          Algeria  13.909
# 2        Argentina  10.084
# 3          Armenia  18.389
# 4            Aruba   7.458
# ..             ...     ...
# 95          Turkey  15.567
# 96         Ukraine   9.318
# 97  United Kingdom   4.375
# 98   United States   9.135
# 99         Uruguay   8.098
#
# [100 rows x 2 columns]

# %%
df_ur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  100 non-null    object
#  1   2021     100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB
