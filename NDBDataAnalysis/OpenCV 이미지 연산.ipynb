# %%
import cv2
image = cv2.imread('cat.png')
# 픽셀 수 및 이미지 크기 확인
print(image.shape)
print(image.size)

# 이미지 Numpy 객체의 특정 픽셀을 가리킵니다.
px = image[100, 100]

# B, G, R 순서로 출력됩니다.
# (단, Gray Scale인 경우에는 B, G, R로 구분되지 않습니다.)
print(px)

# R 값만 출력하기
print(px[2])
# Out:
# (252, 296, 3)
# 223776
# [ 14  68 129]
# 129

# %%
import cv2
import matplotlib.pyplot as plt 
import time

image = cv2.imread('cat.png')

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i, j] = [255, 255, 255]

print("--- %s seconds ---" % (time.time() - start_time))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

start_time = time.time()
image[0:100, 0:100] = [0, 0, 0] # 반복문보다 훨씬 빠름, 일괄 처리
print("--- %s seconds ---" % (time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# --- 0.02207469940185547 seconds ---
# --- 0.000993967056274414 seconds ---

# %%
import cv2
import matplotlib.pyplot as plt 
import time

image = cv2.imread('cat.png')
# Numpy Slicing: ROI 처리 가능
roi = image[100:250, 50:200]
image[0:150, 0:150] = roi

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt 
import time

image = cv2.imread('cat.png')
#특정 색상만 보여주기(0:Blue 1:Green 2:Red)
#cv2.imshow('image', image[:,:,0])
#cv2.waitKey(0)
image[:,:,2] = 255
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#plt.show()
